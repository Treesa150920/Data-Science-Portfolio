# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Importing Data

# %%
data = pd.read_csv('HR-Employee-Attrition.csv')

# %% [markdown]
# # Inspecting Data

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# # Finding Outliers

# %%
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x107680f0b60>,
#   <matplotlib.lines.Line2D at 0x107680f0d40>],
#  'caps': [<matplotlib.lines.Line2D at 0x107680f0140>,
#   <matplotlib.lines.Line2D at 0x107680f1280>],
#  'boxes': [<matplotlib.lines.Line2D at 0x107680f0920>],
#  'medians': [<matplotlib.lines.Line2D at 0x107680f1550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x107680f1850>],
#  'means': []}

# %%
plt.boxplot(data['DailyRate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x107681fa210>,
#   <matplotlib.lines.Line2D at 0x107681fa510>],
#  'caps': [<matplotlib.lines.Line2D at 0x107681fa810>,
#   <matplotlib.lines.Line2D at 0x107681fab40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076818f560>],
#  'medians': [<matplotlib.lines.Line2D at 0x107681fae40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x107681fb0e0>],
#  'means': []}

# %%
plt.boxplot(data['DistanceFromHome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10768261c40>,
#   <matplotlib.lines.Line2D at 0x10768261f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x10768262210>,
#   <matplotlib.lines.Line2D at 0x10768262390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x107682619d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x10768262660>],
#  'fliers': [<matplotlib.lines.Line2D at 0x107682628d0>],
#  'means': []}

# %%
plt.boxplot(data['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x107682cdbe0>,
#   <matplotlib.lines.Line2D at 0x107682cdf10>],
#  'caps': [<matplotlib.lines.Line2D at 0x107682ce240>,
#   <matplotlib.lines.Line2D at 0x107682ce540>],
#  'boxes': [<matplotlib.lines.Line2D at 0x107682cda90>],
#  'medians': [<matplotlib.lines.Line2D at 0x107682ce840>],
#  'fliers': [<matplotlib.lines.Line2D at 0x107682ceae0>],
#  'means': []}

# %%
plt.boxplot(data['MonthlyRate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x107683450d0>,
#   <matplotlib.lines.Line2D at 0x107683453d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x107683456d0>,
#   <matplotlib.lines.Line2D at 0x10768345a00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x10768344e60>],
#  'medians': [<matplotlib.lines.Line2D at 0x10768345c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10768345f40>],
#  'means': []}

# %%
plt.boxplot(data['NumCompaniesWorked'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a3de510>,
#   <matplotlib.lines.Line2D at 0x1076a3de7e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a3deab0>,
#   <matplotlib.lines.Line2D at 0x1076a3ded50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a3de210>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a3df050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a3df350>],
#  'means': []}

# %%
plt.boxplot(data['PercentSalaryHike'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a454200>,
#   <matplotlib.lines.Line2D at 0x1076a4544d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a4547a0>,
#   <matplotlib.lines.Line2D at 0x1076a4549e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a433fb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a454ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a454f80>],
#  'means': []}

# %%
plt.boxplot(data['PerformanceRating'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a4aa540>,
#   <matplotlib.lines.Line2D at 0x1076a4aa7b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a4aaae0>,
#   <matplotlib.lines.Line2D at 0x1076a4aae10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a4aa330>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a4ab110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a4ab3e0>],
#  'means': []}

# %%
plt.boxplot(data['RelationshipSatisfaction'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a51c920>,
#   <matplotlib.lines.Line2D at 0x1076a51cc20>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a51cf20>,
#   <matplotlib.lines.Line2D at 0x1076a51d220>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a51c6e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a51d520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a51d790>],
#  'means': []}

# %%
plt.boxplot(data['HourlyRate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a55f2c0>,
#   <matplotlib.lines.Line2D at 0x1076a55f560>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a55f890>,
#   <matplotlib.lines.Line2D at 0x1076a55fb60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a55f0e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a55fe60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a59c170>],
#  'means': []}

# %%
plt.boxplot(data['TotalWorkingYears'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076b6ee6c0>,
#   <matplotlib.lines.Line2D at 0x1076b6ee960>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076b6eec30>,
#   <matplotlib.lines.Line2D at 0x1076b6eef60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076b6ee4e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076b6ef1a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076b6ef4d0>],
#  'means': []}

# %%
plt.boxplot(data['YearsAtCompany'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076b75e420>,
#   <matplotlib.lines.Line2D at 0x1076b75e6c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076b75e990>,
#   <matplotlib.lines.Line2D at 0x1076b75ec90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076b75e210>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076b718ec0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076b75d0d0>],
#  'means': []}

# %%
plt.boxplot(data['YearsInCurrentRole'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a5c1bb0>,
#   <matplotlib.lines.Line2D at 0x1076a5c1e80>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a5c2150>,
#   <matplotlib.lines.Line2D at 0x1076a5c2390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x107682a8170>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a5c2660>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a5c2990>],
#  'means': []}

# %%
plt.boxplot(data['YearsSinceLastPromotion'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076a60ffb0>,
#   <matplotlib.lines.Line2D at 0x1076a635670>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a6358b0>,
#   <matplotlib.lines.Line2D at 0x1076a635af0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076a635280>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076a635dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a636030>],
#  'means': []}

# %%
plt.boxplot(data['YearsWithCurrManager'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076818e150>,
#   <matplotlib.lines.Line2D at 0x1076a60cf50>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076a60ce00>,
#   <matplotlib.lines.Line2D at 0x1076b6c2ab0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076b71ab10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076b6c1070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076a636390>],
#  'means': []}

# %% [markdown]
# # Removing Outliers

# %%
print(f'Old shape of data: {data.shape}')

q1=data.MonthlyIncome.quantile(0.25)
q3=data.MonthlyIncome.quantile(0.75)
IQR=q3-q1
print(q1,q3,IQR)

lower = q1-1.5*IQR
upper = q3+1.5*IQR

upper_index  = np.where(data['MonthlyIncome'] >= upper)[0]
lower_index  = np.where(data['MonthlyIncome'] <= lower)[0]

data.drop(index = upper_index, inplace=True)
data.drop(index = lower_index, inplace=True)

print(f'New shape of data: {data.shape}')
# Out:
# Old shape of data: (1470, 35)
# 2911.0 8379.0 5468.0
# New shape of data: (1356, 35)

# %%
data.reset_index(inplace=True)

# %%
print(f'Old shape of data: {data.shape}')

q1=data.TotalWorkingYears.quantile(0.25)
q3=data.TotalWorkingYears.quantile(0.75)
IQR=q3-q1
print(q1,q3,IQR)

lower = q1-1.5*IQR
upper = q3+1.5*IQR

upper_index  = np.where(data['TotalWorkingYears'] >= upper)[0]
lower_index  = np.where(data['TotalWorkingYears'] <= lower)[0]

data.drop(index = upper_index, inplace=True)
data.drop(index = lower_index, inplace=True)

print(f'New shape of data: {data.shape}')
# Out:
# Old shape of data: (1356, 36)
# 6.0 13.0 7.0
# New shape of data: (1295, 36)

# %%
data.reset_index(inplace=True)

# %%
print(f'Old shape of data: {data.shape}')

q1=data.YearsAtCompany.quantile(0.25)
q3=data.YearsAtCompany.quantile(0.75)
IQR=q3-q1
print(q1,q3,IQR)

lower = q1-1.5*IQR
upper = q3+1.5*IQR

upper_index  = np.where(data['YearsAtCompany'] >= upper)[0]
lower_index  = np.where(data['YearsAtCompany'] <= lower)[0]

data.drop(index = upper_index, inplace=True)
data.drop(index = lower_index, inplace=True)

print(f'New shape of data: {data.shape}')
# Out:
# Old shape of data: (1295, 37)
# 3.0 9.0 6.0
# New shape of data: (1257, 37)

# %%
data.drop('level_0',axis=1)
# Out:
#       index  Age Attrition     BusinessTravel  DailyRate  \
# 0         0   41       Yes      Travel_Rarely       1102
# 1         1   49        No  Travel_Frequently        279
# 2         2   37       Yes      Travel_Rarely       1373
# 3         3   33        No  Travel_Frequently       1392
# 4         4   27        No      Travel_Rarely        591
# ...     ...  ...       ...                ...        ...
# 1290   1465   36        No  Travel_Frequently        884
# 1291   1466   39        No      Travel_Rarely        613
# 1292   1467   27        No      Travel_Rarely        155
# 1293   1468   49        No  Travel_Frequently       1023
# 1294   1469   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1290  Research & Development                23          2        Medical
# 1291  Research & Development                 6          1        Medical
# 1292  Research & Development                 4          3  Life Sciences
# 1293                   Sales                 2          3        Medical
# 1294  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1290              1  ...                         3             80
# 1291              1  ...                         1             80
# 1292              1  ...                         2             80
# 1293              1  ...                         4             80
# 1294              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1290                1                 17                      3
# 1291                1                  9                      5
# 1292                1                  6                      0
# 1293                0                 17                      3
# 1294                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1290                3              5                   2
# 1291                3              7                   7
# 1292                3              6                   2
# 1293                2              9                   6
# 1294                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1290                       0                     3
# 1291                       1                     7
# 1292                       0                     3
# 1293                       0                     8
# 1294                       1                     2
#
# [1257 rows x 36 columns]

# %%
data.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5740\3756357130.py in ?()
# ----> 1 data.reset_index(inplace=True)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
plt.boxplot(data['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10768086f00>,
#   <matplotlib.lines.Line2D at 0x10768087d10>],
#  'caps': [<matplotlib.lines.Line2D at 0x10768087200>,
#   <matplotlib.lines.Line2D at 0x1076b91d070>],
#  'boxes': [<matplotlib.lines.Line2D at 0x10768086ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076b91e030>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076b91f890>],
#  'means': []}

# %%
plt.boxplot(data['TotalWorkingYears'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076bb711f0>,
#   <matplotlib.lines.Line2D at 0x1076bb47ce0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076bb71610>,
#   <matplotlib.lines.Line2D at 0x1076bb718e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076bb71040>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076bb71bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076bb71df0>],
#  'means': []}

# %%
plt.boxplot(data['YearsAtCompany'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1076bbc29f0>,
#   <matplotlib.lines.Line2D at 0x1076bbc2c90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1076bbc2f30>,
#   <matplotlib.lines.Line2D at 0x1076bbc31d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1076b8b2b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1076bbc3470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1076bbc3710>],
#  'means': []}

# %% [markdown]
# # Dropping useless columns

# %%
data.drop('level_0',axis=1,inplace=True)

# %%
data.drop('index',axis=1,inplace=True)

# %%
data.drop('EmployeeNumber',axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                        1             80
# 1                        3  ...                        4             80
# 2                        4  ...                        2             80
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
# 2                 0                  7                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              6                   4                        0
# 1             10                   7                        1
# 2              0                   0                        0
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
#
# [3 rows x 34 columns]

# %% [markdown]
# # Converting columns to Numeric type

# %%
le_BT = LabelEncoder()
data['BusinessTravel'] = le_BT.fit_transform(data['BusinessTravel'])

le_Dep = LabelEncoder()
data['Department'] = le_Dep.fit_transform(data['Department'])

le_Edu = LabelEncoder()
data['EducationField'] = le_Edu.fit_transform(data['EducationField'])

le_Gen = LabelEncoder()
data['Gender'] = le_Gen.fit_transform(data['Gender'])

le_Jobro = LabelEncoder()
data['JobRole'] = le_Jobro.fit_transform(data['JobRole'])

le_Marst = LabelEncoder()
data['MaritalStatus'] = le_Marst.fit_transform(data['MaritalStatus'])

le_Ov18 = LabelEncoder()
data['Over18'] = le_Ov18.fit_transform(data['Over18'])

le_Ovtim = LabelEncoder()
data['OverTime'] = le_Ovtim.fit_transform(data['OverTime'])

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                       int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
data.shape
# Out:
# (1257, 34)

# %% [markdown]
# # Correlation Analysis

# %%
data
# Out:
#       Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41       Yes               2       1102           2                 1
# 1      49        No               1        279           1                 8
# 2      37       Yes               2       1373           1                 2
# 3      33        No               1       1392           1                 3
# 4      27        No               2        591           1                 2
# ...   ...       ...             ...        ...         ...               ...
# 1290   36        No               1        884           1                23
# 1291   39        No               2        613           1                 6
# 1292   27        No               2        155           1                 4
# 1293   49        No               1       1023           2                 2
# 1294   34        No               2        628           1                 8
#
#       Education  EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# 0             2               1              1                        2  ...
# 1             1               1              1                        3  ...
# 2             2               4              1                        4  ...
# 3             4               1              1                        4  ...
# 4             1               3              1                        1  ...
# ...         ...             ...            ...                      ...  ...
# 1290          2               3              1                        3  ...
# 1291          1               3              1                        4  ...
# 1292          3               1              1                        2  ...
# 1293          3               3              1                        4  ...
# 1294          3               3              1                        2  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                            1             80                 0
# 1                            4             80                 1
# 2                            2             80                 0
# 3                            3             80                 0
# 4                            4             80                 1
# ...                        ...            ...               ...
# 1290                         3             80                 1
# 1291                         1             80                 1
# 1292                         2             80                 1
# 1293                         4             80                 0
# 1294                         1             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1290                 17                      3                3
# 1291                  9                      5                3
# 1292                  6                      0                3
# 1293                 17                      3                2
# 1294                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1290               5                   2                        0
# 1291               7                   7                        1
# 1292               6                   2                        0
# 1293               9                   6                        0
# 1294               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1290                     3
# 1291                     7
# 1292                     3
# 1293                     8
# 1294                     2
#
# [1257 rows x 34 columns]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
new_data=data[['Age', 'DistanceFromHome','MonthlyIncome', 'MonthlyRate','TotalWorkingYears']]

# %%
new_data.corr()
# Out:
#                               Age  DistanceFromHome  MonthlyIncome  \
# Age                      1.000000          0.004976       0.283203
# DistanceFromHome         0.004976          1.000000       0.041184
# MonthlyIncome            0.283203          0.041184       1.000000
# MonthlyRate              0.011420          0.049247       0.063048
# TotalWorkingYears        0.538589          0.047274       0.552624
# YearsAtCompany           0.133177          0.017904       0.347750
# YearsInCurrentRole       0.115464          0.019342       0.327210
# YearsSinceLastPromotion  0.098640          0.015953       0.201475
#
#                          MonthlyRate  TotalWorkingYears  YearsAtCompany  \
# Age                         0.011420           0.538589        0.133177
# DistanceFromHome            0.049247           0.047274        0.017904
# MonthlyIncome               0.063048           0.552624        0.347750
# MonthlyRate                 1.000000           0.000454       -0.027250
# TotalWorkingYears           0.000454           1.000000        0.526586
# YearsAtCompany             -0.027250           0.526586        1.000000
# YearsInCurrentRole         -0.005106           0.466223        0.865349
# YearsSinceLastPromotion    -0.010061           0.293715        0.539675
#
#                          YearsInCurrentRole  YearsSinceLastPromotion
# Age                                0.115464                 0.098640
# DistanceFromHome                   0.019342                 0.015953
# MonthlyIncome                      0.327210                 0.201475
# MonthlyRate                       -0.005106                -0.010061
# TotalWorkingYears                  0.466223                 0.293715
# YearsAtCompany                     0.865349                 0.539675
# YearsInCurrentRole                 1.000000                 0.528093
# YearsSinceLastPromotion            0.528093                 1.000000

# %%
new_data=data[[ 'DistanceFromHome','MonthlyIncome', 'MonthlyRate']]

# %%
sns.pairplot(new_data)

# %%
plt.scatter(data['TotalWorkingYears'],data['MonthlyIncome'],color='green')

# %% [markdown]
# # Summary Statistics

# %%
count = data.Gender.value_counts()
labels = data.Gender.unique()

plt.pie(x=count , labels=labels)

# %%
ab=data['Gender'][:10]
cd=data['Attrition'][:10]
c=range(10)
plt.plot(c,ab, color = 'brown', label='Gender')
plt.plot(c,cd, color = 'red', label='Attrition')

plt.xlabel('Gender')
plt.ylabel('Attrition')
plt.title('multiple line plot',{'fontsize':15,'color':'blue'})
plt.legend()

# %%
sns.pairplot(new_data)
